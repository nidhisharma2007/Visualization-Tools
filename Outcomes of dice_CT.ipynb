# %%
#Assignmet 2
# Total outcomes when two dice are rolled
total_outcomes = 6 * 6

# Outcomes where both dice show the same number
same_faces = 6

# Probability
probability = same_faces / total_outcomes

print("Total outcomes:", total_outcomes)
print("Probability of getting both faces same:", probability)
# Out:
# Total outcomes: 36
# Probability of getting both faces same: 0.16666666666666666
